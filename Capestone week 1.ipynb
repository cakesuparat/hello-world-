# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# The idea of this project is to leverage the foursquare location data to help client identify the best location to open a new restaurant in Toronto. To do this I'm  going to look into proving data about income and population size of each neighborhood and the competitors that already operated in the area.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# In order to provide the client all necessary information, I’ll be online and available datas that contains all information I needed (population, income per household and competitors in the area by using Foursquare API ).

# %% [markdown]
# Here is publicly available data:

# %% [markdown]
# https://www.toronto.ca/city-government/data-research-maps/open-data/open-data-catalogue/#8c732154-5012-9afe-d0cd-ba3ffc813d5a![image.png](attachment:image.png)

# %% [markdown]
# https://www.toronto.ca/city-government/data-research-maps/open-data/open-data-catalogue/#a45bd45a-ede8-730e-1abc-93105b2c439f

# %% [markdown]
# Download library packages

# %%
# !conda install -c conda-forge geopy --yes

# !conda install -c conda-forge folium=0.5.0 --yes

print('Libraries installed!')
